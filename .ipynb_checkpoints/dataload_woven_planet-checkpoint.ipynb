# %% [markdown]
# Исходный туториал находится по ссылке - https://github.com/lyft/nuscenes-devkit/blob/master/notebooks/tutorial_lyft.ipynb

# %%
import os

path = "lyft"
os.chdir(path)

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  '.ipynb_checkpoints',
#  'dataload_woven_planet.ipynb',
#  'Datasets',
#  'download_data_Ford_campus.py',
#  'download_data_woven_planet.py',
#  'download_synthetic_data.py',
#  'lyft',
#  'main.py',
#  'venv']

# %%
# Load the SDK
# %matplotlib inline
from lyft.lyft_dataset_sdk.lyftdataset import LyftDataset

# %%
data_path = "Datasets/Woven_planet/3d-object-detection-train/"
data_json_path = "Datasets/Woven_planet/3d-object-detection-train/train_data"
# Load the dataset
# Adjust the dataroot parameter below to point to your local dataset path.
# The correct dataset path contains at least the following four folders (or similar): images, lidar, maps, v1.0.1-train
level5data = LyftDataset(data_path=data_path,
                         json_path=data_json_path,
                         verbose=True)
# Out:
# 9 category,
# 18 attribute,
# 4 visibility,
# 18421 instance,
# 10 sensor,
# 148 calibrated_sensor,
# 177789 ego_pose,
# 180 log,
# 180 scene,
# 22680 sample,
# 189504 sample_data,
# 638179 sample_annotation,
# 1 map,
# Done loading in 9.2 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 2.5 seconds.
# ======

# %% [markdown]
# 1. **Scene**

# %%
level5data.list_scenes()
# Out:
# host-a007-lidar0-1230485630199365106-12304856550990... [19-01-02 17:33:50]   25s, Palo Alto, #anns:1559
# host-a007-lidar0-1230672860198383106-12306728850991... [19-01-04 21:34:20]   25s, Palo Alto, #anns:2969
# host-a007-lidar0-1230936221299185986-12309362461986... [19-01-07 22:43:41]   25s, Palo Alto, #anns:683
# host-a007-lidar0-1231093036199514746-12310930610996... [19-01-09 18:17:16]   25s, Palo Alto, #anns:3117
# host-a009-lidar0-1231200854198312986-12312008790984... [19-01-11 00:14:14]   25s, Palo Alto, #anns:681
# host-a005-lidar0-1231201437298603426-12312014621988... [19-01-11 00:23:57]   25s, Palo Alto, #anns:3064
# host-a011-lidar0-1232401360198078026-12324013850983... [19-01-24 21:42:40]   25s, Palo Alto, #anns:3842
# host-a011-lidar0-1232412236198491106-12324122610982... [19-01-25 00:43:56]   25s, Palo Alto, #anns:372
# host-a007-lidar0-1232470052198454586-12324700770988... [19-01-25 16:47:32]   25s, Palo Alto, #anns:1614
# host-a011-lidar0-1232485958298280666-12324859832000... [19-01-25 21:12:38]   25s, Palo Alto, #anns:5119
# host-a007-lidar0-1232490767197744146-12324907920986... [19-01-25 22:32:47]   25s, Palo Alto, #anns:3074
# host-a011-lidar0-1232492192198952026-12324922170988... [19-01-25 22:56:32]   25s, Palo Alto, #anns:829
# host-a011-lidar0-1232731591298977986-12327316161978... [19-01-28 17:26:31]   25s, Palo Alto, #anns:575
# host-a011-lidar0-1232732468299489666-12327324931990... [19-01-28 17:41:08]   25s, Palo Alto, #anns:832
# host-a007-lidar0-1232736726098319676-12327367509994... [19-01-28 18:52:06]   25s, Palo Alto, #anns:2586
# host-a011-lidar0-1232738595197630316-12327386200984... [19-01-28 19:23:15]   25s, Palo Alto, #anns:4137
# Out:
# {'log_token': 'da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952e158e5589854af9f100',
#  'first_sample_token': '24b0962e44420e6322de3f25d9e4e5cc3c7a348ec00bfa69db21517e4ca92cc8',
#  'name': 'host-a101-lidar0-1241893239199111666-1241893264098084346',
#  'description': '',
#  'last_sample_token': '2346756c83f6ae8c4d1adec62b4d0d31b62116d2e1819e96e9512667d15e7cec',
#  'nbr_samples': 126,
#  'token': 'da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952e158e5589854af9f100'}

# %% [markdown]
# 2. **Sample**
#
# We define sample as an *annotated keyframe of a scene at a given timestamp*. A keyframe is a frame where the time-stamps of data from all the sensors should be very close to the time-stamp of the sample it points to.
#
# Now, let us look at the first annotated sample in this scene.

# %%
my_sample_token = my_scene["first_sample_token"]
# my_sample_token = level5data.get("sample", my_sample_token)["next"]  # proceed to next sample

level5data.render_sample(my_sample_token)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 4
#       1 my_sample_token = my_scene["first_sample_token"]
#       2 # my_sample_token = level5data.get("sample", my_sample_token)["next"]  # proceed to next sample
# ----> 4 level5data.render_sample(my_sample_token)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:484, in LyftDataset.render_sample(self, sample_token, box_vis_level, nsweeps, out_path)
#     477 def render_sample(
#     478     self,
#     479     sample_token: str,
#    (...)
#     482     out_path: str = None,
#     483 ) -> None:
# --> 484     self.explorer.render_sample(sample_token, box_vis_level, nsweeps=nsweeps, out_path=out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:880, in LyftDatasetExplorer.render_sample(self, token, box_vis_level, nsweeps, out_path)
#     878 # Plot camera and lidar in separate subplots.
#     879 for (_, sd_token), ax in zip(nonradar_data.items(), axes.flatten()[num_radar_plots:]):
# --> 880     self.render_sample_data(sd_token, box_vis_level=box_vis_level, ax=ax, num_sweeps=nsweeps)
#     882 axes.flatten()[-1].axis("off")
#     883 plt.tight_layout()
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1087, in LyftDatasetExplorer.render_sample_data(self, sample_data_token, with_annotations, box_vis_level, axes_limit, ax, num_sweeps, out_path, underlay_map)
#    1083     ax.set_ylim(-axes_limit, axes_limit)
#    1085 elif sensor_modality == "camera":
#    1086     # Load boxes and image.
# -> 1087     data_path, boxes, camera_intrinsic = self.lyftd.get_sample_data(
#    1088         sample_data_token, box_vis_level=box_vis_level
#    1089     )
#    1091     data = Image.open(data_path)
#    1093     # Init axes.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %%
my_sample = level5data.get('sample', my_sample_token)
my_sample
# Out:
# {'next': 'c2ba18e4414ce9038ad52efab44e1a0a211ff1e6b297a632805000510756174d',
#  'prev': '',
#  'token': '24b0962e44420e6322de3f25d9e4e5cc3c7a348ec00bfa69db21517e4ca92cc8',
#  'timestamp': 1557858039302414.8,
#  'scene_token': 'da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952e158e5589854af9f100',
#  'data': {'CAM_BACK': '542a9e44f2e26221a6aa767c2a9b90a9f692c3aee2edb7145256b61e666633a4',
#   'CAM_FRONT_ZOOMED': '9c9bc711d93d728666f5d7499703624249919dd1b290a477fcfa39f41b26259e',
#   'LIDAR_FRONT_RIGHT': '8cfae06bc3d5d7f9be081f66157909ff18c9f332cc173d962460239990c7a4ff',
#   '9d09fe62334a19c5091ec0240ff7d428051789b4626af4aaa0765b68e9d39233',
#   'c95c21676d9e40d6c9fdbc09b63b7262cdd7e17fb79749d6484d3e188fe4e465',
#   '4863dfbe3958ba0019825875f6787bf9f823055c244c7e5c835953aaac0e5840',
#   'a4111990f3a4f8507517a1005c3661aa4fbe2b9dca5678334f1a271617e9465b',
#   '4be9e7e3656a5b306d07b0545b04757d9a6b976207777d9cb82c8e28106c5ba7',
#   '844858e20360441a0f527d056ec16e5b4ba5d040b23dd2e3e4e5392f571e4f11',
#   'eeead57502d696864ada2307b3ce053c57baba4579fb4a1cee4fa2b8c4fb2a6d']}

# %% [markdown]
# A useful method is list_sample() which lists all related sample_data keyframes and sample_annotation associated with a sample which we will discuss in detail in the subsequent parts.

# %%
level5data.list_sample(my_sample['token'])
# Out:
# Sample: 24b0962e44420e6322de3f25d9e4e5cc3c7a348ec00bfa69db21517e4ca92cc8
#
# sample_data_token: 542a9e44f2e26221a6aa767c2a9b90a9f692c3aee2edb7145256b61e666633a4, mod: camera, channel: CAM_BACK
# sample_data_token: 9c9bc711d93d728666f5d7499703624249919dd1b290a477fcfa39f41b26259e, mod: camera, channel: CAM_FRONT_ZOOMED
# sample_data_token: 8cfae06bc3d5d7f9be081f66157909ff18c9f332cc173d962460239990c7a4ff, mod: lidar, channel: LIDAR_FRONT_RIGHT
# sample_data_token: fb40b3b5b9d289cd0e763bec34e327d3317a7b416f787feac0d387363b4d00f0, mod: camera, channel: CAM_FRONT
# sample_data_token: f47a5d143bcebb24efc269b1a40ecb09440003df2c381a69e67cd2a726b27a0c, mod: camera, channel: CAM_FRONT_LEFT
# sample_data_token: 5dc54375a9e14e8398a538ff97fbbee7543b6f5df082c60fc4477c919ba83a40, mod: camera, channel: CAM_FRONT_RIGHT
# sample_data_token: ae8754c733560aa2506166cfaf559aeba670407631badadb065a9ffe7c337a7d, mod: camera, channel: CAM_BACK_RIGHT
# sample_data_token: 01c0eecd4b56668e949143e02a117b5683025766d186920099d1e918c23c8b4b, mod: camera, channel: CAM_BACK_LEFT
# sample_data_token: ec9950f7b5d4ae85ae48d07786e09cebbf4ee771d054353f1e24a95700b4c4af, mod: lidar, channel: LIDAR_TOP
# sample_data_token: 5c3d79e1cf8c8182b2ceefa33af96cbebfc71f92e18bf64eb8d4e0bf162e01d4, mod: lidar, channel: LIDAR_FRONT_LEFT
#
# sample_annotation_token: 2a03c42173cde85f5829995c5851cc81158351e276db493b96946882059a5875, category: car
# sample_annotation_token: c3c663ed5e7b6456ab27f09175743a551b0b31676dae71fbeef3420dfc6c7b09, category: car
# sample_annotation_token: 4193e4bf217c8a0ff598d792bdd9d049b496677d5172e38c1ed22394f20274fb, category: pedestrian
# sample_annotation_token: f543b455c7066d7054ed5218670b4432a3fc7a0f57cadb0cb59aa96e8dd1a135, category: truck
# sample_annotation_token: 6ef405e1f47a4a234f0bfeeb559d61c70031af6c47bf2e499a31002f845cd403, category: pedestrian
# sample_annotation_token: 4863dfbe3958ba0019825875f6787bf9f823055c244c7e5c835953aaac0e5840, category: car
# sample_annotation_token: a4111990f3a4f8507517a1005c3661aa4fbe2b9dca5678334f1a271617e9465b, category: car
# sample_annotation_token: 4be9e7e3656a5b306d07b0545b04757d9a6b976207777d9cb82c8e28106c5ba7, category: car
# sample_annotation_token: 844858e20360441a0f527d056ec16e5b4ba5d040b23dd2e3e4e5392f571e4f11, category: truck
# sample_annotation_token: eeead57502d696864ada2307b3ce053c57baba4579fb4a1cee4fa2b8c4fb2a6d, category: car

# %% [markdown]
# Instead of looking at camera and lidar data separately, we can also project the lidar pointcloud into camera images:

# %%
level5data.render_pointcloud_in_image(sample_token = my_sample["token"],
                                      dot_size = 1,
                                      camera_channel = 'CAM_FRONT')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 level5data.render_pointcloud_in_image(sample_token = my_sample["token"],
#       2                                       dot_size = 1,
#       3                                       camera_channel = 'CAM_FRONT')
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:469, in LyftDataset.render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path)
#     461 def render_pointcloud_in_image(
#     462     self,
#     463     sample_token: str,
#    (...)
#     467     out_path: str = None,
#     468 ) -> None:
# --> 469     self.explorer.render_pointcloud_in_image(
#     470         sample_token,
#     471         dot_size,
#     472         pointsensor_channel=pointsensor_channel,
#     473         camera_channel=camera_channel,
#     474         out_path=out_path,
#     475     )
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:826, in LyftDatasetExplorer.render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path)
#     823 pointsensor_token = sample_record["data"][pointsensor_channel]
#     824 camera_token = sample_record["data"][camera_channel]
# --> 826 points, coloring, im = self.map_pointcloud_to_image(pointsensor_token, camera_token)
#     827 plt.figure(figsize=(9, 16))
#     828 plt.imshow(im)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:752, in LyftDatasetExplorer.map_pointcloud_to_image(self, pointsensor_token, camera_token)
#     750 pcl_path = self.lyftd.data_path / pointsensor["filename"]
#     751 if pointsensor["sensor_modality"] == "lidar":
# --> 752     pc = LidarPointCloud.from_file(pcl_path)
#     753 else:
#     754     pc = RadarPointCloud.from_file(pcl_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\venv\lib\site-packages\lyft_dataset_sdk\utils\data_classes.py:285, in LidarPointCloud.from_file(cls, file_name)
#     274 """Loads LIDAR data from binary numpy format. Data is stored as (x, y, z, intensity, ring index).
#     275
#     276 Args:
#    (...)
#     280
#     281 """
#     283 assert file_name.suffix == ".bin", "Unsupported filetype {}".format(file_name)
# --> 285 scan = np.fromfile(str(file_name), dtype=np.float32)
#     286 points = scan.reshape((-1, 5))[:, : cls.nbr_dims()]
#     287 return cls(points.T)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Download_Softwares\\PyCharm\\Projects\\VKR_Model\\Datasets\\Woven_planet\\3d-object-detection-train\\lidar\\host-a101_lidar1_1241893239302414726.bin'

# %% [markdown]
# 3. Sample_data
#
# The dataset contains data that is collected from a full sensor suite. Hence, for each snapshot of a scene, we provide references to a family of data that is collected from these sensors.
#
# We provide a data key to access these:

# %%
my_sample["data"]
# Out:
# {'CAM_BACK': '542a9e44f2e26221a6aa767c2a9b90a9f692c3aee2edb7145256b61e666633a4',
#  'CAM_FRONT_ZOOMED': '9c9bc711d93d728666f5d7499703624249919dd1b290a477fcfa39f41b26259e',
#  'LIDAR_FRONT_RIGHT': '8cfae06bc3d5d7f9be081f66157909ff18c9f332cc173d962460239990c7a4ff',
#  'CAM_FRONT': 'fb40b3b5b9d289cd0e763bec34e327d3317a7b416f787feac0d387363b4d00f0',
#  'CAM_FRONT_LEFT': 'f47a5d143bcebb24efc269b1a40ecb09440003df2c381a69e67cd2a726b27a0c',
#  'CAM_FRONT_RIGHT': '5dc54375a9e14e8398a538ff97fbbee7543b6f5df082c60fc4477c919ba83a40',
#  'CAM_BACK_RIGHT': 'ae8754c733560aa2506166cfaf559aeba670407631badadb065a9ffe7c337a7d',
#  'CAM_BACK_LEFT': '01c0eecd4b56668e949143e02a117b5683025766d186920099d1e918c23c8b4b',
#  'LIDAR_TOP': 'ec9950f7b5d4ae85ae48d07786e09cebbf4ee771d054353f1e24a95700b4c4af',
#  'LIDAR_FRONT_LEFT': '5c3d79e1cf8c8182b2ceefa33af96cbebfc71f92e18bf64eb8d4e0bf162e01d4'}

# %% [markdown]
# Notice that the keys are referring to the different sensors that form our sensor suite. Let's take a look at the metadata of a sample_data taken from CAM_FRONT.

# %%
sensor_channel = 'CAM_FRONT'  # also try this e.g. with 'LIDAR_TOP'
my_sample_data = level5data.get('sample_data', my_sample['data'][sensor_channel])
my_sample_data
# Out:
# {'width': 1920,
#  'height': 1080,
#  'calibrated_sensor_token': '8e73e320d1fa9e5af96059e6eb1dd7d28e3271dea04de86ead47fa25fd13fd20',
#  'token': 'fb40b3b5b9d289cd0e763bec34e327d3317a7b416f787feac0d387363b4d00f0',
#  'sample_token': '24b0962e44420e6322de3f25d9e4e5cc3c7a348ec00bfa69db21517e4ca92cc8',
#  'is_key_frame': True,
#  'prev': '',
#  'fileformat': 'jpeg',
#  'ego_pose_token': '0c257254dad346c9d90f7970ce2c0b8142f7c6e6a90716f4c0538cd2d2ef77d5',
#  'timestamp': 1557858039250000.0,
#  'next': '00ba71deb97524b5d9be9b677962b74bb32f89284ad7838462250218786b903e',
#  'filename': 'images/host-a101_cam0_1241893239250000006.jpeg',
#  'sensor_modality': 'camera',
#  'channel': 'CAM_FRONT'}

# %% [markdown]
# We can also render the sample_data at a particular sensor.

# %%
level5data.render_sample_data(my_sample_data['token'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 level5data.render_sample_data(my_sample_data['token'])
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:497, in LyftDataset.render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map)
#     486 def render_sample_data(
#     487     self,
#     488     sample_data_token: str,
#    (...)
#     495     underlay_map: bool = False,
#     496 ):
# --> 497     return self.explorer.render_sample_data(
#     498         sample_data_token,
#     499         with_anns,
#     500         box_vis_level,
#     501         axes_limit,
#     502         ax,
#     503         num_sweeps=nsweeps,
#     504         out_path=out_path,
#     505         underlay_map=underlay_map,
#     506     )
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1087, in LyftDatasetExplorer.render_sample_data(self, sample_data_token, with_annotations, box_vis_level, axes_limit, ax, num_sweeps, out_path, underlay_map)
#    1083     ax.set_ylim(-axes_limit, axes_limit)
#    1085 elif sensor_modality == "camera":
#    1086     # Load boxes and image.
# -> 1087     data_path, boxes, camera_intrinsic = self.lyftd.get_sample_data(
#    1088         sample_data_token, box_vis_level=box_vis_level
#    1089     )
#    1091     data = Image.open(data_path)
#    1093     # Init axes.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# 4. **Sample_annotation**
#
# sample_annotation refers to any *bounding box defining the position of an object seen in a sample*. All location data is given with respect to the global coordinate system. Let's examine an example from our sample above.

# %%
my_annotation_token = my_sample['anns'][16]
my_annotation =  my_sample_data.get('sample_annotation', my_annotation_token)
my_annotation
# Out:
# '1ec543ca38666e906886b71f662f45f1605344410e26962a58668a7511ba65ce'

# %% [markdown]
# We can also render an annotation to have a closer look.

# %%
level5data.render_annotation(my_annotation_token)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 level5data.render_annotation(my_annotation_token)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:516, in LyftDataset.render_annotation(self, sample_annotation_token, margin, view, box_vis_level, out_path)
#     508 def render_annotation(
#     509     self,
#     510     sample_annotation_token: str,
#    (...)
#     514     out_path: str = None,
#     515 ) -> None:
# --> 516     self.explorer.render_annotation(sample_annotation_token, margin, view, box_vis_level, out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1155, in LyftDatasetExplorer.render_annotation(self, ann_token, margin, view, box_vis_level, out_path)
#    1153 cams = [key for key in sample_record["data"].keys() if "CAM" in key]
#    1154 for cam in cams:
# -> 1155     _, boxes, _ = self.lyftd.get_sample_data(
#    1156         sample_record["data"][cam], box_vis_level=box_vis_level, selected_anntokens=[ann_token]
#    1157     )
#    1158     if len(boxes) > 0:
#    1159         break  # We found an image that matches. Let's abort.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# 5. **Instance**
#
# Object instance are instances that need to be detected or tracked by an AV (e.g a particular vehicle, pedestrian). Let us examine an instance metadata

# %%
my_instance = level5data.instance[100]
my_instance
# Out:
# {'last_annotation_token': '17be5c0175d3f4e36b9829d4789a6174d531637587107a0bfa1f3668d1ed9a57',
#  'category_token': '8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0ae338d97aff2dbcb9c',
#  'token': '0984d7f7d64a8a03523e43ea01c7292488bd73ae745514077b28a9dc240b9f95',
#  'first_annotation_token': 'b1f924cb04786ef4d46810ef8c3e7fe17597d4464507267dc56dcfbe1faa6581',
#  'nbr_annotations': 56}

# %% [markdown]
# We generally track an instance across different frames in a particular scene. However, we do not track them across different scenes. In this example, we have 16 annotated samples for this instance across a particular scene.

# %%
instance_token = my_instance['token']
level5data.render_instance(instance_token)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 2
#       1 instance_token = my_instance['token']
# ----> 2 level5data.render_instance(instance_token)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:519, in LyftDataset.render_instance(self, instance_token, out_path)
#     518 def render_instance(self, instance_token: str, out_path: str = None) -> None:
# --> 519     self.explorer.render_instance(instance_token, out_path=out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1214, in LyftDatasetExplorer.render_instance(self, instance_token, out_path)
#    1212         closest[0] = dist
#    1213         closest[1] = ann_token
# -> 1214 self.render_annotation(closest[1], out_path=out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1155, in LyftDatasetExplorer.render_annotation(self, ann_token, margin, view, box_vis_level, out_path)
#    1153 cams = [key for key in sample_record["data"].keys() if "CAM" in key]
#    1154 for cam in cams:
# -> 1155     _, boxes, _ = self.lyftd.get_sample_data(
#    1156         sample_record["data"][cam], box_vis_level=box_vis_level, selected_anntokens=[ann_token]
#    1157     )
#    1158     if len(boxes) > 0:
#    1159         break  # We found an image that matches. Let's abort.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# An instance record takes note of its first and last annotation token. Let's render them
#
# First annotated sample of this instance:

# %%
print("First annotated sample of this instance:")
level5data.render_annotation(my_instance['first_annotation_token'])
# Out:
# First annotated sample of this instance:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 print("First annotated sample of this instance:")
# ----> 2 level5data.render_annotation(my_instance['first_annotation_token'])
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:516, in LyftDataset.render_annotation(self, sample_annotation_token, margin, view, box_vis_level, out_path)
#     508 def render_annotation(
#     509     self,
#     510     sample_annotation_token: str,
#    (...)
#     514     out_path: str = None,
#     515 ) -> None:
# --> 516     self.explorer.render_annotation(sample_annotation_token, margin, view, box_vis_level, out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1155, in LyftDatasetExplorer.render_annotation(self, ann_token, margin, view, box_vis_level, out_path)
#    1153 cams = [key for key in sample_record["data"].keys() if "CAM" in key]
#    1154 for cam in cams:
# -> 1155     _, boxes, _ = self.lyftd.get_sample_data(
#    1156         sample_record["data"][cam], box_vis_level=box_vis_level, selected_anntokens=[ann_token]
#    1157     )
#    1158     if len(boxes) > 0:
#    1159         break  # We found an image that matches. Let's abort.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# Last annotated sample of this instance

# %%
print("Last annotated sample of this instance")
level5data.render_annotation(my_instance['last_annotation_token'])
# Out:
# Last annotated sample of this instance
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 print("Last annotated sample of this instance")
# ----> 2 level5data.render_annotation(my_instance['last_annotation_token'])
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:516, in LyftDataset.render_annotation(self, sample_annotation_token, margin, view, box_vis_level, out_path)
#     508 def render_annotation(
#     509     self,
#     510     sample_annotation_token: str,
#    (...)
#     514     out_path: str = None,
#     515 ) -> None:
# --> 516     self.explorer.render_annotation(sample_annotation_token, margin, view, box_vis_level, out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1155, in LyftDatasetExplorer.render_annotation(self, ann_token, margin, view, box_vis_level, out_path)
#    1153 cams = [key for key in sample_record["data"].keys() if "CAM" in key]
#    1154 for cam in cams:
# -> 1155     _, boxes, _ = self.lyftd.get_sample_data(
#    1156         sample_record["data"][cam], box_vis_level=box_vis_level, selected_anntokens=[ann_token]
#    1157     )
#    1158     if len(boxes) > 0:
#    1159         break  # We found an image that matches. Let's abort.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# 6. **Category**
#
# A category is the object assignment of an annotation. Let's look at the category table we have in our database. The table contains the taxonomy of different object categories and also list the subcategories (delineated by a period).

# %%
level5data.list_categories()
# Out:
# Category stats
# animal                      n=  186, width= 0.36±0.12, len= 0.73±0.19, height= 0.51±0.16, lw_aspect= 2.16±0.56
# bicycle                     n=20928, width= 0.63±0.24, len= 1.76±0.29, height= 1.44±0.37, lw_aspect= 3.20±1.17
# bus                         n= 8729, width= 2.96±0.24, len=12.34±3.41, height= 3.44±0.31, lw_aspect= 4.17±1.10
# car                         n=534911, width= 1.93±0.16, len= 4.76±0.53, height= 1.72±0.24, lw_aspect= 2.47±0.22
# emergency_vehicle           n=  132, width= 2.45±0.43, len= 6.52±1.44, height= 2.39±0.59, lw_aspect= 2.66±0.28
# motorcycle                  n=  818, width= 0.96±0.20, len= 2.35±0.22, height= 1.59±0.16, lw_aspect= 2.53±0.50
# other_vehicle               n=33376, width= 2.79±0.30, len= 8.20±1.71, height= 3.23±0.50, lw_aspect= 2.93±0.53
# pedestrian                  n=24935, width= 0.77±0.14, len= 0.81±0.17, height= 1.78±0.16, lw_aspect= 1.06±0.20
# truck                       n=14164, width= 2.84±0.32, len=10.24±4.09, height= 3.44±0.62, lw_aspect= 3.56±1.25

# %% [markdown]
# A category record contains the name and the description of that particular category.

# %%
level5data.category[2]
# Out:
# {'description': '',
#  'token': 'f81f51e1897311b55c0c6247c3db825466733e08df687c0ea830b026316a1c12',
#  'name': 'animal'}

# %% [markdown]
# 7. **Attribute**
#
# An attribute is a property of an instance that may change throughout different parts of a scene while the category remains the same. Here we list the provided attributes and the number of annotations associated with a particular attribute.

# %%
level5data.list_attributes()
# Out:
# is_stationary: 321981
# object_action_abnormal_or_traffic_violation: 2
# object_action_driving_straight_forward: 244805
# object_action_gliding_on_wheels: 165
# object_action_lane_change_left: 1463
# object_action_lane_change_right: 1370
# object_action_left_turn: 5074
# object_action_loss_of_control: 1
# object_action_other_motion: 582
# object_action_parked: 257939
# object_action_reversing: 278
# object_action_right_turn: 6694
# object_action_running: 621
# object_action_sitting: 586
# object_action_standing: 5332
# object_action_stopped: 94970
# object_action_u_turn: 407
# object_action_walking: 17890

# %% [markdown]
# Let's take a look at an example how an attribute may change over one scene

# %%
for my_instance in level5data.instance:
    first_token = my_instance['first_annotation_token']
    last_token = my_instance['last_annotation_token']
    nbr_samples = my_instance['nbr_annotations']
    current_token = first_token

    i = 0
    found_change = False
    while current_token != last_token:
        current_ann = level5data.get('sample_annotation', current_token)
        current_attr = level5data.get('attribute', current_ann['attribute_tokens'][0])['name']

        if i == 0:
            pass
        elif current_attr != last_attr:
            print("Changed from `{}` to `{}` at timestamp {} out of {} annotated timestamps".format(last_attr, current_attr, i, nbr_samples))
            found_change = True

        next_token = current_ann['next']
        current_token = next_token
        last_attr = current_attr
        i += 1
# Out:
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 1 out of 39 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 12 out of 39 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_left_turn` at timestamp 42 out of 72 annotated timestamps
# Changed from `object_action_left_turn` to `object_action_driving_straight_forward` at timestamp 66 out of 72 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 19 out of 47 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 39 out of 47 annotated timestamps
# Changed from `object_action_stopped` to `object_action_driving_straight_forward` at timestamp 23 out of 88 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_lane_change_left` at timestamp 27 out of 88 annotated timestamps
# Changed from `object_action_lane_change_left` to `object_action_driving_straight_forward` at timestamp 43 out of 88 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 27 out of 78 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 54 out of 78 annotated timestamps
# Changed from `object_action_walking` to `object_action_standing` at timestamp 1 out of 52 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_stopped` at timestamp 22 out of 89 annotated timestamps
# Changed from `object_action_stopped` to `object_action_driving_straight_forward` at timestamp 9 out of 44 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_stopped` at timestamp 10 out of 44 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 70 out of 97 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 25 out of 72 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_stopped` at timestamp 46 out of 72 annotated timestamps
# Changed from `object_action_stopped` to `object_action_right_turn` at timestamp 67 out of 72 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 29 out of 59 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 48 out of 59 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 91 out of 126 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 115 out of 126 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_stopped` at timestamp 10 out of 71 annotated timestamps
# Changed from `object_action_stopped` to `object_action_right_turn` at timestamp 24 out of 71 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 37 out of 71 annotated timestamps
# Changed from `object_action_stopped` to `object_action_driving_straight_forward` at timestamp 41 out of 126 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_left_turn` at timestamp 71 out of 126 annotated timestamps
# Changed from `object_action_left_turn` to `object_action_driving_straight_forward` at timestamp 100 out of 126 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 18 out of 37 annotated timestamps
# Changed from `object_action_standing` to `object_action_walking` at timestamp 51 out of 125 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_stopped` at timestamp 37 out of 47 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_stopped` at timestamp 8 out of 31 annotated timestamps
# Changed from `object_action_walking` to `object_action_running` at timestamp 11 out of 106 annotated timestamps
# Changed from `object_action_running` to `object_action_walking` at timestamp 69 out of 106 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_lane_change_right` at timestamp
annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 10 out of 42 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 28 out of 42 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_lane_change_right` at timestamp 59 out of 114 annotated timestamps
# Changed from `object_action_lane_change_right` to `object_action_stopped` at timestamp 93 out of 114 annotated timestamps
# Changed from `object_action_stopped` to `object_action_driving_straight_forward` at timestamp 19 out of 30 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_stopped` at timestamp 28 out of 30 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_left_turn` at timestamp 15 out of 48 annotated timestamps
# Changed from `object_action_left_turn` to `object_action_driving_straight_forward` at timestamp 37 out of 48 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 3 out of 22 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 21 out of 30 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_stopped` at timestamp 51 out of 71 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 9 out of 38 annotated timestamps
# Changed from `object_action_stopped` to `object_action_driving_straight_forward` at timestamp 11 out of 51 annotated timestamps
# Changed from `object_action_left_turn` to `object_action_driving_straight_forward` at timestamp 20 out of 53 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 4 out of 50 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_left_turn` at timestamp 18 out of 50 annotated timestamps
# Changed from `object_action_left_turn` to `object_action_right_turn` at timestamp 34 out of 50 annotated timestamps
# Changed from `object_action_lane_change_left` to `object_action_driving_straight_forward` at timestamp 26 out of 56 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 19 out of 64 annotated timestamps
# Changed from `object_action_driving_straight_forward` to `object_action_right_turn` at timestamp 28 out of 64 annotated timestamps
# Changed from `object_action_right_turn` to `object_action_driving_straight_forward` at timestamp 53 out of 64 annotated timestamps

# %% [markdown]
# 8. **Sensor**
#
# The Level 5 dataset consists of data collected from our full sensor suite which consists of:
#
# * 1 x LIDAR, (up to three in final dataset)
# * 7 x cameras,

# %%
level5data.sensor
# Out:
# [{'modality': 'camera',
#   'channel': 'CAM_FRONT_LEFT',
#   'token': 'f7dad6bb70cb8e6245f96e5537e382848335872e6e259218b0a80cc071d162c4'},
#  {'modality': 'lidar',
#   'channel': 'LIDAR_FRONT_LEFT',
#   'token': '629da739ea3a0814b9d79ffc3b99cdbc8bdbb6f97abf139f1ad33bd12f8fa94d'},
#  {'modality': 'camera',
#   'channel': 'CAM_FRONT',
#   'token': 'eb9e8f60a3d6e3328d7512b9f8e6800127fe91f4d62bc8e48a0e6a7cb116cc60'},
#  {'modality': 'lidar',
#   'channel': 'LIDAR_TOP',
#   'token': '25bf751d7e35f295393d8a418731474b21c1f702e878c4553f112397caa48c08'},
#  {'modality': 'camera',
#   'channel': 'CAM_BACK_LEFT',
#   'token': 'c84592e22beb2c0f14d5159245ce8d6678431b879e940eed580651c09cc7d2f1'},
#  {'modality': 'lidar',
#   'channel': 'LIDAR_FRONT_RIGHT',
#   'token': '953faed96fd3d2fae3ec03cd2838b312b8c1a9bb7a0629481982870cb28acb67'},
#  {'modality': 'camera',
#   'channel': 'CAM_BACK',
#   'token': '172a55e2b50f18a6b6d545369a457003c2f3b438d0180b2b4c7819ca29b3f6ab'},
#  {'modality': 'camera',
#   'channel': 'CAM_BACK_RIGHT',
#   'token': '8e0259a868ddbfe589c2ce9c8bfb34a9e6c19c108b882c45433c76b70a2491a2'},
#  {'modality': 'camera',
#   'channel': 'CAM_FRONT_ZOOMED',
#   'token': '286718e1fbc8c8f0ca441969d91c36a8a809666e049e54ce121636100b520946'},
#  {'modality': 'camera',
#   'channel': 'CAM_FRONT_RIGHT',
#   'token': 'de29f3ebb9d96988ac2c5913022c3102a51134e950284aac2e8511f83aff9a81'}]

# %%
level5data.sample_data[10]
# Out:
# {'is_key_frame': True,
#  'fileformat': 'bin',
#  'prev': '89e066a61d09acfb201c91d9f2b9bef2d89d96a22ab41efb09704a1319567872',
#  'calibrated_sensor_token': '7efae113b75a3c387bb2a92439be7e795e5caabd5819b4e9b6f89e8955c87a44',
#  'token': '5146c66963a2100cc5850485741dbf30aae6fc500a684be1ff677d45d2a5b616',
#  'timestamp': 1551388503101689.8,
#  'next': '3f2ef26d47f69a1f0ad69393d065fd8d29fcdcb5a0cf0340b3522102d48862ce',
#  'ego_pose_token': 'c51a6d17e3c5c17d0a4a8a0208785143b060d954dd78bb93ec4653b4897fc87d',
#  'sample_token': '2bd45a80fba943914188bc31fa3bc8a5b9b4156da4376cede52d76347b1ac7ef',
#  'filename': 'lidar/host-a015_lidar1_1235423703101689806.bin',
#  'sensor_modality': 'lidar',
#  'channel': 'LIDAR_TOP'}

# %% [markdown]
# 9. **Calibrated_sensor**
#
# calibrated_sensor consists of the definition of a particular sensor (lidar/camera) as calibrated on a particular vehicle. Let us look at an example.

# %%
level5data.calibrated_sensor[0]
# Out:
# {'sensor_token': 'c84592e22beb2c0f14d5159245ce8d6678431b879e940eed580651c09cc7d2f1',
#  'rotation': [-0.6784803059109364,
#   0.6875255645268346,
#   0.1910946403595628,
#   -0.1745162199880262],
#  'camera_intrinsic': [[882.42699274, 0, 602.047851885],
#   [0.0, 882.42699274, 527.99972239],
#   [0.0, 0.0, 1.0]],
#  'translation': [1.0399186259366102, 0.30857658859026604, 1.65459751959659],
#  'token': '80349b63ead8bfe5f4ce2cbe27fed9e4b5d699a5fc422232349263d21cd5eb70'}

# %% [markdown]
# Note that the translation and the rotation parameters are given with respect to the ego vehicle body frame.

# %% [markdown]
# 10. **Ego_pose**
#
# ego_pose contains information about the location (encoded in translation) and the orientation (encoded in rotation) of the ego vehicle body frame, with respect to the global coordinate system.

# %%
level5data.ego_pose[0]
# Out:
# {'rotation': [0.8045437502844562,
#   0.02410792365998265,
#   0.016871015279640935,
#   0.5931639998672046],
#  'translation': [622.726103039258, 3460.3733051620957, -6.813459358283256],
#  'token': '2de7c52546f3f9bf6734084da8a2c1edaa0ffbea7f6e86f76a6ea66593d9a26b',
#  'timestamp': 1547165667901671.8}

# %% [markdown]
# 11. **log**
#
# The log table contains log information from which the data was extracted. A log record corresponds to one journey of our ego vehicle along a predefined route. Let's check the number of logs and the metadata of a log.

# %%
print("Number of `logs` in our loaded database: {}".format(len(level5data.log)))
# Out:
# Number of `logs` in our loaded database: 180

# %%
level5data.log[0]
# Out:
# {'date_captured': '2019-05-14',
#  'location': 'Palo Alto',
#  'token': 'da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952e158e5589854af9f100',
#  'vehicle': 'a101',
#  'logfile': '',
#  'map_token': '53992ee3023e5494b90c316c183be829'}

# %% [markdown]
# Notice that it contains a variety of information such as the date and location of the log collected. It also gives out information about the map from where the data was collected. Note that one log can contain multiple non-overlapping scenes.

# %% [markdown]
# 12. **Map**
#
# Map information is currently stored in a 2D rasterized image. Let's check the number of maps and metadata of a map.

# %%
#   'a6afe4a83e2c29d41f7b31159449458bb5acc5fcc95feadaf19110de6b6eeacc',
#   '06257d5293de02fdf8d525d6c563ac308b6028e6fb43432b229ea4263d8fff38',
#   '67fc193bdbf42a68f53daa3f93d1c7fe84106e434c25c9931ebca02c2367cc96',
#   '0cf3165e68d24e3cf1c735d093b85f7031d0f91f6842fd05de230f2085e1c7a3',
#   '8246aafd339a991f4946d83b7fc9770e53b4f2cfdcf9f941b123a060ba56613b',
#   'aa243f3bbd8aab5bebcbe89a8ca5b0964499d58331dc1395fa3b5f324c79e305',
#   '3c4f82dd8c5fb7bf3ddcbdf5dce573d46ed0fcd8c6d7e15effdecb7bf2919463',
#   '6dd3732001cfc0db51344fa96af64f9aff307c573e476c20648421d1823874ea',
#   'a243e4030032f9891590c99965be0eb95e0cce9a22011ca019ac1e38a71dd1bb',
#   '1b9f5bb4ce2a527abe8fd420728a00c6c66ff623b1473664f38cdb33bc6d2290',
#   '51b7bdbcb4d856e7da7c26a5693d20371a2e58f8ae5f5ee991759cef257b47fc',
#   'fc98c2ebbda4665104a2b1e1573488c6da66dc1f4e7eb6800bf4c6fbf237e60f',
#   'a33b172a90802dcc0e2dfef123d36bbb4eee33ebfb3939e13a3b737674d23d19',
#   '9d0166ccd4af9c089738587f6e3d21cd9c8b6102787427da8c3b4f64161160c5',
#   'a5ae88dfb74f4477a0bd0cae3ec82588bcf081ce4125b871c3c24389abc0578d',
#   'dade599b4c186ccde906db20beb010f7b71e6c1d60817888d98a868e32436631',
#   '3c807ceae63a47150351dfc0856262d780f7fbbb48608cef72395be15b43b56a',
#   'b28b767dac46db1659065a51d6453129eeb82bf397fdbb779de95414090d6842',
#   'd23bc414dd4c48a55e24d80d86cc54f393ea20649f381af567b53644b761b40a'],
#  'token': '53992ee3023e5494b90c316c183be829',
#  'filename': 'maps/map_raster_palo_alto.png',
#  'category': 'semantic_prior',
#  'mask': <lyft_dataset_sdk.utils.map_mask.MapMask at 0x178d411f280>}

# %% [markdown]
# The map can e.g. be displayed in the background of top-down views:

# %%
sensor_channel = 'LIDAR_TOP'
my_sample_data = level5data.get('sample_data', my_sample['data'][sensor_channel])
# The following call can be slow and requires a lot of memory
level5data.render_sample_data(my_sample_data['token'], underlay_map = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 4
#       2 my_sample_data = level5data.get('sample_data', my_sample['data'][sensor_channel])
#       3 # The following call can be slow and requires a lot of memory
# ----> 4 level5data.render_sample_data(my_sample_data['token'], underlay_map = True)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:497, in LyftDataset.render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map)
#     486 def render_sample_data(
#     487     self,
#     488     sample_data_token: str,
#    (...)
#     495     underlay_map: bool = False,
#     496 ):
# --> 497     return self.explorer.render_sample_data(
#     498         sample_data_token,
#     499         with_anns,
#     500         box_vis_level,
#     501         axes_limit,
#     502         ax,
#     503         num_sweeps=nsweeps,
#     504         out_path=out_path,
#     505         underlay_map=underlay_map,
#     506     )
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:971, in LyftDatasetExplorer.render_sample_data(self, sample_data_token, with_annotations, box_vis_level, axes_limit, ax, num_sweeps, out_path, underlay_map)
#     967 sensor_modality = sd_record["sensor_modality"]
#     969 if sensor_modality == "lidar":
#     970     # Get boxes in lidar frame.
# --> 971     _, boxes, _ = self.lyftd.get_sample_data(
#     972         sample_data_token, box_vis_level=box_vis_level, flat_vehicle_coordinates=True
#     973     )
#     975     # Get aggregated point cloud in lidar frame.
#     976     sample_rec = self.lyftd.get("sample", sd_record["sample_token"])
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:286, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     283     yaw = ypr[0]
#     285     box.translate(-np.array(pose_record["translation"]))
# --> 286     box.rotate_around_origin(Quaternion(scalar=np.cos(yaw / 2), vector=[0, 0, np.sin(yaw / 2)]).inverse)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# **Dataset and Devkit Basics**
#
# Let's get a bit technical.
#
# The NuScenes class holds several tables. Each table is a list of records, and each record is a dictionary. For example the first record of the category table is stored at:

# %%
level5data.category[0]
# Out:
# {'description': '',
#  'token': '8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0ae338d97aff2dbcb9c',
#  'name': 'car'}

# %% [markdown]
# The category table is simple: it holds the fields name and description. It also has a token field, which is a unique record identifier. Since the record is a dictionary, the token can be accessed like so:

# %%
cat_token = level5data.category[0]['token']
cat_token
# Out:
# '8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0ae338d97aff2dbcb9c'

# %% [markdown]
# If you know the token for any record in the DB you can retrieve the record by doing

# %%
level5data.get('category', cat_token)
# Out:
# {'description': '',
#  'token': '8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0ae338d97aff2dbcb9c',
#  'name': 'car'}

# %% [markdown]
# *As you can notice, we have recovered the same record!*
#
# OK, that was easy. Let's try something harder. Let's look at the sample_annotation table.

# %%
level5data.sample_annotation[0]
# Out:
# {'token': '92bff46db1dbfc9679edc8091770c4256ac3c027e9f0a9c31dfc4fff41f6f677',
#  'num_lidar_pts': -1,
#  'size': [2.064, 5.488, 2.053],
#  'sample_token': 'db8b47bd4ebdf3b3fb21598bb41bd8853d12f8d2ef25ce76edd4af4d04e49341',
#  'rotation': [0.265491936795379, 0, 0, 0.964113080243515],
#  'prev': 'db2c5aea69d8be40a746c5f3df9366e030189b07647212f338b31240c15896df',
#  'translation': [2680.2830359778527, 698.1969292852777, -18.04776692365821],
#  'num_radar_pts': 0,
#  'attribute_tokens': ['1ba8c9a8bda54423fa710b0af1441d849ecca8ed7b7f9393ba1794afe4aa6aa2',
#   'daf16a3f6499553cc5e1df4a456de5ee46e2e6b06544686d918dfb1ddb088f6f'],
#  'next': '33e07b849d62718279c9548fe662d32247e319f0451cd461059305c3e42dcea0',
#  'instance_token': 'abea2eb040d9c8fa1a44fa54020daaf9e2aa696e95e1d257481ecbf6e13a318c',
#  'visibility_token': '',
#  'category_name': 'car'}

# %% [markdown]
# This also has a `token` field (they all do). In addition, it has several fields of the format [a-z]*_token, e.g. instance_token. These are foreign keys in database speak, meaning they point to another table. Using `level5data.get()` we can grab any of these in constant time.
#
# Note that in our dataset, we don't provide `num_lidar_pts` and set it to `-1` to indicate this.

# %%
one_instance = level5data.get('instance', level5data.sample_annotation[0]['instance_token'])
one_instance
# Out:
# {'category_token': '8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0ae338d97aff2dbcb9c',
#  'last_annotation_token': '1b7d368056d75ac9082d30c84a4ffc2468cccc960aad11f1c171ec66390c8fff',
#  'token': 'abea2eb040d9c8fa1a44fa54020daaf9e2aa696e95e1d257481ecbf6e13a318c',
#  'first_annotation_token': '754eca53d8bce9fdc0da74ed71b35f83690bb8a8c8d5fa8e8d22d9d68031af33',
#  'nbr_annotations': 100}

# %% [markdown]
# This points to the `instance` table. This table enumerate the object instances we have encountered in each scene. This way we can connect all annotations of a particular object.
#
# If you look carefully at the tables, you will see that the sample_annotation table points to the instance table, but the instance table doesn't list all annotations that point to it.
#
# So how can we recover all sample_annotations for a particular object instance? There are two ways:
#
# 1. `Use level5data.field2token()`. Let's try it:

# %%
ann_tokens = level5data.field2token('sample_annotation', 'instance_token', one_instance['token'])

# %% [markdown]
# This returns a list of all sample_annotation records with the `'instance_token'` == `one_instance['token']`. Let's store these in a set for now

# %%
ann_tokens_field2token = set(ann_tokens)

ann_tokens_field2token
# Out:
# {'00564bd5209801b04c9aa1043b3caafe50cf6cb5d5c671b2d8a01365a0275978',
#  '01697ff7f0c690d81b047a4fad745af5277b6b9ee79a54431339fd2a8988d859',
#  '064442ccc8d9c39465ff4907fe411fcc41c00c22a63c177f7f7eda467e06b805',
#  '0a76a4500aae16f84ea1ae38520d710ae4a43543be446e87e26cdb153f57f7fe',
#  '0c01c1b96ed4cc4fea95448268eb256d654e4a6d82ce53c74173ca10d1e9f873',
#  '102094e87c9a175a38c0875464d9e16ff3c995f038f92fc938d167f68234fe99',
#  '180106df5b012b5895e941afa9d94d14c7b543e5413bf85e553a9a971367a2de',
#  '198bb5deb603d6f3be122343733a43ea6be72449e2a858456b62baaf1f99d24b',
#  '1b55260770aaa73f049af65daf946df4265117cdc82a1fd90e141a91240c963b',
#  '1b7d368056d75ac9082d30c84a4ffc2468cccc960aad11f1c171ec66390c8fff',
#  '1e24f09d58f86f6f8cd5d00402fff8b8ce861ce44571ec2e37d0165ec7fce089',
#  '1fe45db03656a63267d0f36e86a1a1da478f1d9e0955d6360293c457acce3a58',
#  '20db03a9d0cad10d83e900b7e37f3ea667380ff2f12f78e54622baee8d54d3df',
#  '22b5b1c3ab28b0ff30b95489ea6ea035b4eb776dcfae14d82bd4f91478891afe',
#  '28c67291ea1d32641e70809b20919ef50ad989c2f2dd46303eaeb11ea3866831',
#  '32b9fc1d51d0f82dee2a23eeeb3a8c982e85278d0c68071456cff28948e9f63f',
#  '3307af70cd0792b964e91e2e30842c804496a4c754bfbfb1e4deaeb71b3d5ae9',
#  '33e07b849d62718279c9548fe662d32247e319f0451cd461059305c3e42dcea0',
#  '34a3d4b8209bee8f1f47d7019fa3cc2439a7cdaaf943fa74478748435d8cb524',
#  '3787c96c3f29192775f4df336e0bffc49180514d279852accc2b28b967c575bf',
#  '3a758baad2a3d0aef4eefcd8e783a24c51e4d77208343c1ff7bbb228c92cdb1b',
#  'db2c5aea69d8be40a746c5f3df9366e030189b07647212f338b31240c15896df',
#  'df5043c0e7894efd45e6ab5ca23a32284f02989e830b613bbc0dd2f46f86ca21',
#  'df8aaa2831557f3dcd855181bd831921690e82d3f69a2d5363faa0e5527f74fc',
#  'e8a7570f7db0b6d5177a505ae2356e24ba735eab98d68d7fd626bd77a098bfab',
#  'e949782a84c2c059b36e7a846e93ea59a428706904473607428ad13dcb0f32fa',
#  'efa0b2faa41ec2c50697a595062eb90fc1846cfd2b3c0c69cc195be009db39ca',
#  'f0677407b288f3672df76fa9a0593d44a059d5a947e4b10fbea43a00df625464',
#  'f5245b1ded6a3fcf7c3b1d93345c73094f9279c854115a50dbd65ec17d967505',
#  'f595fa5a37b82282df5fc350e0bd0547f0caddeb3c22e377c6509d799b1af535',
#  'fb3b718a92cf214791fe2ea2863e40cec285912c8094042d62c4495437c669c3',
#  'fb9a81ce1b6bbf21f94ecbc5f9b9343e6b0b9091b0bb158f8659994be51df7b2',
#  'fd14c1f1c2209b01569fbd74469cb9852701b352f2d41bdf141ec08346910d9d',
#  'fd54e17ce8c67efbfcade8e692b73899656ed3250d930d395720c2fba4748349',
#  'fd5d7ea817866de63fbada1897449ed76d6d7bb30bc476f72f640b61e63a88a1',
#  'ff9a6277f9a3eb9e7ccd2d05488525cb67d8d5391b0019cfd761715c7106cadc'}

# %% [markdown]
# The `level5data.field2token()` method is generic and can be used in any similar situation.
#
# 2. For certain situation, we provide some reverse indices in the tables themselves. This is one such example.
#
# The instance record has a field `first_annotation_token` which points to the first annotation in time of this instance. Recovering this record is easy.

# %%
ann_record = level5data.get('sample_annotation', one_instance['first_annotation_token'])
ann_record
# Out:
# {'token': '754eca53d8bce9fdc0da74ed71b35f83690bb8a8c8d5fa8e8d22d9d68031af33',
#  'num_lidar_pts': -1,
#  'size': [2.064, 5.488, 2.053],
#  'sample_token': 'c625a4ee6a19df449a18a829e2f903e1750e872923253f57903300da071959b3',
#  'rotation': [0.265491936795379, 0, 0, 0.964113080243515],
#  'prev': '',
#  'translation': [2680.2830359778527, 698.1969292852777, -18.04776692365821],
#  'num_radar_pts': 0,
#  'attribute_tokens': ['1ba8c9a8bda54423fa710b0af1441d849ecca8ed7b7f9393ba1794afe4aa6aa2',
#   'daf16a3f6499553cc5e1df4a456de5ee46e2e6b06544686d918dfb1ddb088f6f'],
#  'next': '840ed3ed6763d413aa0c71b57a17a1c7d57f6160eddd88abbebc5615bd57051d',
#  'instance_token': 'abea2eb040d9c8fa1a44fa54020daaf9e2aa696e95e1d257481ecbf6e13a318c',
#  'visibility_token': '',
#  'category_name': 'car'}

# %% [markdown]
# Now we can traverse all annotations of this instance using the "next" field. Let's try it.

# %%
ann_tokens_traverse = set()
ann_tokens_traverse.add(ann_record['token'])
while not ann_record['next'] == "":
    ann_record = level5data.get('sample_annotation', ann_record['next'])
    ann_tokens_traverse.add(ann_record['token'])

# %% [markdown]
# Finally, let's assert that we recovered the same ann_records as we did using level5data.field2token:

# %%
print(ann_tokens_traverse == ann_tokens_field2token)
# Out:
# True

# %% [markdown]
# **Reverse indexing and short-cuts**
#
# The dataset tables are normalized, meaning that each piece of information is only given once. For example, there is one `map` record for each `log` record. Looking at the schema you will notice that the `map` table has a `log_token` field, but that the `log` table does not have a corresponding `map_token` field. But there are plenty of situations where you have a `log`, and want to find the corresponding `map`! So what to do? You can always use the `level5data.field2token()` method, but that is slow and inconvenient. The devkit therefore adds reverse mappings for some common situations including this one.
#
# Further, there are situations where one needs to go through several tables to get a certain piece of information. Consider, for example, the category name of a `sample_annotation`. The `sample_annotation` table doesn't hold this information since the category is an instance level constant. Instead the `sample_annotation` table points to a record in the `instance` table. This, in turn, points to a record in the `category` table, where finally the `name` fields stores the required information.
#
# Since it is quite common to want to know the category name of an annotation, we add a `category_name` field to the `sample_annotation` table during initialization of the NuScenes class.
#
# In this section, we list the short-cuts and reverse indices that are added to the `NuScenes` class during initialization. These are all created in the `NuScenes.__make_reverse_index__()` method.
#
# **Reverse indices**
#
# The devkit adds two reverse indices by default.
#
# * A `map_token` field is added to the `log` records.
# * The `sample` records have shortcuts to all `sample_annotations` for that record as well as `sample_data` key-frames. Confer `level5data.list_sample()` method in the previous section for more details on this.
#
# **Shortcuts**
#
# The sample_annotation table has a "category_name" shortcut.
#
# *Using shortcut:*

# %%
catname = level5data.sample_annotation[0]['category_name']

# %% [markdown]
# *Not using shortcut:*

# %%
ann_rec = level5data.sample_annotation[0]
inst_rec = level5data.get('instance', ann_rec['instance_token'])
cat_rec = level5data.get('category', inst_rec['category_token'])

print(catname == cat_rec['name'])
# Out:
# True

# %% [markdown]
# The sample_data table has "channel" and "sensor_modality" shortcuts:

# %%
# Shortcut
channel = level5data.sample_data[0]['channel']

# No shortcut
sd_rec = level5data.sample_data[0]
cs_record = level5data.get('calibrated_sensor', sd_rec['calibrated_sensor_token'])
sensor_record = level5data.get('sensor', cs_record['sensor_token'])

print(channel == sensor_record['channel'])
# Out:
# True

# %% [markdown]
# **Data Visualizations**
#
# We provide list and rendering methods. These are meant both as convenience methods during development, and as tutorials for building your own visualization methods. They are implemented in the NuScenesExplorer class, with shortcuts through the NuScenes class itself.
#
# **List methods**
#
# There are three list methods available.
#
# 1. list_categories() lists all categories, counts and statistics of width/length/height in meters and aspect ratio.

# %%
level5data.list_categories()
# Out:
# Category stats
# animal                      n=  186, width= 0.36±0.12, len= 0.73±0.19, height= 0.51±0.16, lw_aspect= 2.16±0.56
# bicycle                     n=20928, width= 0.63±0.24, len= 1.76±0.29, height= 1.44±0.37, lw_aspect= 3.20±1.17
# bus                         n= 8729, width= 2.96±0.24, len=12.34±3.41, height= 3.44±0.31, lw_aspect= 4.17±1.10
# car                         n=534911, width= 1.93±0.16, len= 4.76±0.53, height= 1.72±0.24, lw_aspect= 2.47±0.22
# emergency_vehicle           n=  132, width= 2.45±0.43, len= 6.52±1.44, height= 2.39±0.59, lw_aspect= 2.66±0.28
# motorcycle                  n=  818, width= 0.96±0.20, len= 2.35±0.22, height= 1.59±0.16, lw_aspect= 2.53±0.50
# other_vehicle               n=33376, width= 2.79±0.30, len= 8.20±1.71, height= 3.23±0.50, lw_aspect= 2.93±0.53
# pedestrian                  n=24935, width= 0.77±0.14, len= 0.81±0.17, height= 1.78±0.16, lw_aspect= 1.06±0.20
# truck                       n=14164, width= 2.84±0.32, len=10.24±4.09, height= 3.44±0.62, lw_aspect= 3.56±1.25

# %% [markdown]
# 2. `list_attributes()` lists all attributes and counts.

# %%
level5data.list_attributes()
# Out:
# is_stationary: 321981
# object_action_abnormal_or_traffic_violation: 2
# object_action_driving_straight_forward: 244805
# object_action_gliding_on_wheels: 165
# object_action_lane_change_left: 1463
# object_action_lane_change_right: 1370
# object_action_left_turn: 5074
# object_action_loss_of_control: 1
# object_action_other_motion: 582
# object_action_parked: 257939
# object_action_reversing: 278
# object_action_right_turn: 6694
# object_action_running: 621
# object_action_sitting: 586
# object_action_standing: 5332
# object_action_stopped: 94970
# object_action_u_turn: 407
# object_action_walking: 17890

# %% [markdown]
# 3. `list_scenes()` lists all scenes in the loaded DB.

# %%
level5data.list_scenes()
# Out:
# host-a007-lidar0-1230485630199365106-12304856550990... [19-01-02 17:33:50]   25s, Palo Alto, #anns:1559
# host-a007-lidar0-1230672860198383106-12306728850991... [19-01-04 21:34:20]   25s, Palo Alto, #anns:2969
# host-a007-lidar0-1230936221299185986-12309362461986... [19-01-07 22:43:41]   25s, Palo Alto, #anns:683
# host-a007-lidar0-1231093036199514746-12310930610996... [19-01-09 18:17:16]   25s, Palo Alto, #anns:3117
# host-a009-lidar0-1231200854198312986-12312008790984... [19-01-11 00:14:14]   25s, Palo Alto, #anns:681
# host-a005-lidar0-1231201437298603426-12312014621988... [19-01-11 00:23:57]   25s, Palo Alto, #anns:3064
# host-a011-lidar0-1232401360198078026-12324013850983... [19-01-24 21:42:40]   25s, Palo Alto, #anns:3842
# host-a011-lidar0-1232412236198491106-12324122610982... [19-01-25 00:43:56]   25s, Palo Alto, #anns:372
# host-a007-lidar0-1232470052198454586-12324700770988... [19-01-25 16:47:32]   25s, Palo Alto, #anns:1614
# host-a011-lidar0-1232485958298280666-12324859832000... [19-01-25 21:12:38]   25s, Palo Alto, #anns:5119
# host-a007-lidar0-1232490767197744146-12324907920986... [19-01-25 22:32:47]   25s, Palo Alto, #anns:3074
# host-a011-lidar0-1232492192198952026-12324922170988... [19-01-25 22:56:32]   25s, Palo Alto, #anns:829
# host-a011-lidar0-1232731591298977986-12327316161978... [19-01-28 17:26:31]   25s, Palo Alto, #anns:575
# host-a011-lidar0-1232732468299489666-12327324931990... [19-01-28 17:41:08]   25s, Palo Alto, #anns:832
# host-a007-lidar0-1232736726098319676-12327367509994... [19-01-28 18:52:06]   25s, Palo Alto, #anns:2586
# host-a011-lidar0-1232738595197630316-12327386200984... [19-01-28 19:23:15]   25s, Palo Alto, #anns:4137
# host-a011-lidar0-1232745770199275666-12327457950995... [19-01-28 21:22:50]   25s, Palo Alto, #anns:4667
# host-a011-lidar0-1232752461198357666-12327524860997... [19-01-28 23:14:21]   25s, Palo Alto, #anns:1689

# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[83], line 2
#       1 my_sample = level5data.sample[10]
# ----> 2 level5data.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='LIDAR_TOP')
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:469, in LyftDataset.render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path)
#     461 def render_pointcloud_in_image(
#     462     self,
#     463     sample_token: str,
#    (...)
#     467     out_path: str = None,
#     468 ) -> None:
# --> 469     self.explorer.render_pointcloud_in_image(
#     470         sample_token,
#     471         dot_size,
#     472         pointsensor_channel=pointsensor_channel,
#     473         camera_channel=camera_channel,
#     474         out_path=out_path,
#     475     )
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:826, in LyftDatasetExplorer.render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path)
#     823 pointsensor_token = sample_record["data"][pointsensor_channel]
#     824 camera_token = sample_record["data"][camera_channel]
# --> 826 points, coloring, im = self.map_pointcloud_to_image(pointsensor_token, camera_token)
#     827 plt.figure(figsize=(9, 16))
#     828 plt.imshow(im)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:752, in LyftDatasetExplorer.map_pointcloud_to_image(self, pointsensor_token, camera_token)
#     750 pcl_path = self.lyftd.data_path / pointsensor["filename"]
#     751 if pointsensor["sensor_modality"] == "lidar":
# --> 752     pc = LidarPointCloud.from_file(pcl_path)
#     753 else:
#     754     pc = RadarPointCloud.from_file(pcl_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\venv\lib\site-packages\lyft_dataset_sdk\utils\data_classes.py:285, in LidarPointCloud.from_file(cls, file_name)
#     274 """Loads LIDAR data from binary numpy format. Data is stored as (x, y, z, intensity, ring index).
#     275
#     276 Args:
#    (...)
#     280
#     281 """
#     283 assert file_name.suffix == ".bin", "Unsupported filetype {}".format(file_name)
# --> 285 scan = np.fromfile(str(file_name), dtype=np.float32)
#     286 points = scan.reshape((-1, 5))[:, : cls.nbr_dims()]
#     287 return cls(points.T)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Download_Softwares\\PyCharm\\Projects\\VKR_Model\\Datasets\\Woven_planet\\3d-object-detection-train\\lidar\\host-a007_lidar1_1233079641101768046.bin'

# %% [markdown]
# We can also plot all annotations across all sample data for that sample.

# %%
my_sample = level5data.sample[20]

# The rendering command below is commented out because it tends to crash in notebooks
# level5data.render_sample(my_sample['token'])

# %% [markdown]
# Or if we only want to render a particular sensor, we can specify that.

# %%
level5data.render_sample_data(my_sample['data']['CAM_FRONT'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 level5data.render_sample_data(my_sample['data']['CAM_FRONT'])
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:497, in LyftDataset.render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map)
#     486 def render_sample_data(
#     487     self,
#     488     sample_data_token: str,
#    (...)
#     495     underlay_map: bool = False,
#     496 ):
# --> 497     return self.explorer.render_sample_data(
#     498         sample_data_token,
#     499         with_anns,
#     500         box_vis_level,
#     501         axes_limit,
#     502         ax,
#     503         num_sweeps=nsweeps,
#     504         out_path=out_path,
#     505         underlay_map=underlay_map,
#     506     )
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1087, in LyftDatasetExplorer.render_sample_data(self, sample_data_token, with_annotations, box_vis_level, axes_limit, ax, num_sweeps, out_path, underlay_map)
#    1083     ax.set_ylim(-axes_limit, axes_limit)
#    1085 elif sensor_modality == "camera":
#    1086     # Load boxes and image.
# -> 1087     data_path, boxes, camera_intrinsic = self.lyftd.get_sample_data(
#    1088         sample_data_token, box_vis_level=box_vis_level
#    1089     )
#    1091     data = Image.open(data_path)
#    1093     # Init axes.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# Additionally we can aggregate the point clouds from multiple sweeps to get a denser point cloud.

# %%
level5data.render_sample_data(my_sample['data']['LIDAR_TOP'], nsweeps=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 level5data.render_sample_data(my_sample['data']['LIDAR_TOP'], nsweeps=5)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:497, in LyftDataset.render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map)
#     486 def render_sample_data(
#     487     self,
#     488     sample_data_token: str,
#    (...)
#     495     underlay_map: bool = False,
#     496 ):
# --> 497     return self.explorer.render_sample_data(
#     498         sample_data_token,
#     499         with_anns,
#     500         box_vis_level,
#     501         axes_limit,
#     502         ax,
#     503         num_sweeps=nsweeps,
#     504         out_path=out_path,
#     505         underlay_map=underlay_map,
#     506     )
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:971, in LyftDatasetExplorer.render_sample_data(self, sample_data_token, with_annotations, box_vis_level, axes_limit, ax, num_sweeps, out_path, underlay_map)
#     967 sensor_modality = sd_record["sensor_modality"]
#     969 if sensor_modality == "lidar":
#     970     # Get boxes in lidar frame.
# --> 971     _, boxes, _ = self.lyftd.get_sample_data(
#     972         sample_data_token, box_vis_level=box_vis_level, flat_vehicle_coordinates=True
#     973     )
#     975     # Get aggregated point cloud in lidar frame.
#     976     sample_rec = self.lyftd.get("sample", sd_record["sample_token"])
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:286, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     283     yaw = ypr[0]
#     285     box.translate(-np.array(pose_record["translation"]))
# --> 286     box.rotate_around_origin(Quaternion(scalar=np.cos(yaw / 2), vector=[0, 0, np.sin(yaw / 2)]).inverse)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# We can even render a specific annotation.

# %%
level5data.render_annotation(my_sample['anns'][22])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 level5data.render_annotation(my_sample['anns'][22])
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:516, in LyftDataset.render_annotation(self, sample_annotation_token, margin, view, box_vis_level, out_path)
#     508 def render_annotation(
#     509     self,
#     510     sample_annotation_token: str,
#    (...)
#     514     out_path: str = None,
#     515 ) -> None:
# --> 516     self.explorer.render_annotation(sample_annotation_token, margin, view, box_vis_level, out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1155, in LyftDatasetExplorer.render_annotation(self, ann_token, margin, view, box_vis_level, out_path)
#    1153 cams = [key for key in sample_record["data"].keys() if "CAM" in key]
#    1154 for cam in cams:
# -> 1155     _, boxes, _ = self.lyftd.get_sample_data(
#    1156         sample_record["data"][cam], box_vis_level=box_vis_level, selected_anntokens=[ann_token]
#    1157     )
#    1158     if len(boxes) > 0:
#    1159         break  # We found an image that matches. Let's abort.
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# Finally, we can render a full scene as a video. There are two options here:
#
# 1. level5data.render_scene_channel() renders the video for a particular channel. (HIT ESC to exit)
# 2. level5data.render_scene() renders the video for all surround view camera channels.
#
# NOTE: These methods use OpenCV for rendering, which doesn't always play nice with IPython Notebooks. If you experience any issues please run these lines from the command line.

# %%
my_scene_token = level5data.scene[0]["token"]
level5data.render_scene_channel(my_scene_token, 'CAM_FRONT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 2
#       1 my_scene_token = level5data.scene[0]["token"]
# ----> 2 level5data.render_scene_channel(my_scene_token, 'CAM_FRONT')
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:534, in LyftDataset.render_scene_channel(self, scene_token, channel, freq, imsize, out_path, interactive, verbose)
#     524 def render_scene_channel(
#     525     self,
#     526     scene_token: str,
#    (...)
#     532     verbose: bool = False,
#     533 ) -> None:
# --> 534     self.explorer.render_scene_channel(
#     535         scene_token=scene_token,
#     536         channel=channel,
#     537         freq=freq,
#     538         image_size=imsize,
#     539         out_path=out_path,
#     540         interactive=interactive,
#     541         verbose=verbose,
#     542     )
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1398, in LyftDatasetExplorer.render_scene_channel(self, scene_token, channel, freq, image_size, out_path, interactive, verbose)
#    1395     print(sd_rec["token"])
#    1397 # Get data from DB
# -> 1398 image_path, boxes, camera_intrinsic = self.lyftd.get_sample_data(
#    1399     sd_rec["token"], box_vis_level=BoxVisibility.ANY
#    1400 )
#    1402 # Load and render
#    1403 if not image_path.exists():
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# There is also a method level5data.render_scene() which renders the video for all camera channels.

# %%
level5data.render_scene(my_scene_token)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 level5data.render_scene(my_scene_token)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:522, in LyftDataset.render_scene(self, scene_token, freq, imwidth, out_path)
#     521 def render_scene(self, scene_token: str, freq: float = 10, imwidth: int = 640, out_path: str = None) -> None:
# --> 522     self.explorer.render_scene(scene_token, freq, image_width=imwidth, out_path=out_path)
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:1292, in LyftDatasetExplorer.render_scene(self, scene_token, freq, image_width, out_path)
#    1286 for channel, sd_rec in current_recs.items():
#    1287
#    1288     # Only update canvas if we have not already rendered this one.
#    1289     if not sd_rec == prev_recs[channel]:
#    1290
#    1291         # Get annotations and params from DB.
# -> 1292         image_path, boxes, camera_intrinsic = self.lyftd.get_sample_data(
#    1293             sd_rec["token"], box_vis_level=BoxVisibility.ANY
#    1294         )
#    1296         # Load and render
#    1297         if not image_path.exists():
#
# File C:\Download_Softwares\PyCharm\Projects\VKR_Model\lyft\lyft_dataset_sdk\lyftdataset.py:291, in LyftDataset.get_sample_data(self, sample_data_token, box_vis_level, selected_anntokens, flat_vehicle_coordinates)
#     288 else:
#     289     # Move box to ego vehicle coord system
#     290     box.translate(-np.array(pose_record["translation"]))
# --> 291     box.rotate_around_origin(Quaternion(pose_record["rotation"]).inverse)
#     293     #  Move box to sensor coord system
#     294     box.translate(-np.array(cs_record["translation"]))
#
# AttributeError: 'Box' object has no attribute 'rotate_around_origin'

# %% [markdown]
# Finally, let us visualize all scenes on the map for a particular location.

# %%
level5data.render_egoposes_on_map(log_location='Palo Alto')
# Out:
# Adding ego poses to map...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 180/180 [01:16<00:00,  2.36it/s]
# Creating plot...

# %% [markdown]
# **Play with it!**
#
# E.g.:
#
# 1. Plot 5 sequential lidar scans with underlying semantic map.

# %%
# put your code here
# hint: 
# next_sample_data = level5data.get('sample_data', my_sample_data["next"])
# gives you the next sample data entry

# %% [markdown]
# 2. Show an annotation at the moment when an attribute changes.

# %%
level5data.render_sample_3d_interactive(
    sample_id='f7ca3cda9fbd6d8793be14389e87a79da9715aa40c2baf4d037b9fdacc8010cf',
    render_sample=False
)
